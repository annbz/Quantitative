# %%
#pip install starfishX
# Out:
# Collecting starfishX
#   Downloading starfishX-0.155537-py3-none-any.whl (113 kB)
# Collecting pythainlp
#   Downloading pythainlp-3.0.8-py3-none-any.whl (11.5 MB)
# Collecting tvdatafeed
#   Downloading tvdatafeed-1.2.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: pandas in c:\users\ann_1\anaconda3\lib\site-packages (from starfishX) (1.3.4)
# Collecting selenium
#   Downloading selenium-4.3.0-py3-none-any.whl (981 kB)
# Requirement already satisfied: seaborn in c:\users\ann_1\anaconda3\lib\site-packages (from starfishX) (0.11.2)
# Collecting mplfinance
#   Downloading mplfinance-0.12.9b1-py3-none-any.whl (70 kB)
# Collecting ffn
#   Downloading ffn-0.3.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\ann_1\anaconda3\lib\site-packages (from starfishX) (4.10.0)
# Requirement already satisfied: urllib3 in c:\users\ann_1\anaconda3\lib\site-packages (from starfishX) (1.26.7)
# Requirement already satisfied: html5lib in c:\users\ann_1\anaconda3\lib\site-packages (from starfishX) (1.1)
# Requirement already satisfied: tqdm in c:\users\ann_1\anaconda3\lib\site-packages (from starfishX) (4.62.3)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied: scipy in c:\users\ann_1\anaconda3\lib\site-packages (from starfishX) (1.7.1)
# Collecting pyqt5
#   Downloading PyQt5-5.15.7-cp37-abi3-win_amd64.whl (6.8 MB)
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Requirement already satisfied: requests in c:\users\ann_1\anaconda3\lib\site-packages (from starfishX) (2.26.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ann_1\anaconda3\lib\site-packages (from beautifulsoup4->starfishX) (2.2.1)
# Requirement already satisfied: pandas-datareader>=0.2 in c:\users\ann_1\anaconda3\lib\site-packages (from ffn->starfishX) (0.10.0)
# Requirement already satisfied: scikit-learn>=0.15 in c:\users\ann_1\anaconda3\lib\site-packages (from ffn->starfishX) (1.0.2)
# Requirement already satisfied: numpy>=1.5 in c:\users\ann_1\anaconda3\lib\site-packages (from ffn->starfishX) (1.20.3)
# Requirement already satisfied: decorator>=4 in c:\users\ann_1\anaconda3\lib\site-packages (from ffn->starfishX) (5.1.0)
# Requirement already satisfied: future>=0.15 in c:\users\ann_1\anaconda3\lib\site-packages (from ffn->starfishX) (0.18.2)
# Requirement already satisfied: matplotlib>=1 in c:\users\ann_1\anaconda3\lib\site-packages (from ffn->starfishX) (3.4.3)
# Requirement already satisfied: tabulate>=0.7.5 in c:\users\ann_1\anaconda3\lib\site-packages (from ffn->starfishX) (0.8.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ann_1\anaconda3\lib\site-packages (from matplotlib>=1->ffn->starfishX) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ann_1\anaconda3\lib\site-packages (from matplotlib>=1->ffn->starfishX) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ann_1\anaconda3\lib\site-packages (from matplotlib>=1->ffn->starfishX) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ann_1\anaconda3\lib\site-packages (from matplotlib>=1->ffn->starfishX) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ann_1\anaconda3\lib\site-packages (from matplotlib>=1->ffn->starfishX) (8.4.0)
# Requirement already satisfied: six in c:\users\ann_1\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=1->ffn->starfishX) (1.16.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pytz>=2017.3 in c:\users\ann_1\anaconda3\lib\site-packages (from pandas->starfishX) (2021.3)
# Requirement already satisfied: lxml in c:\users\ann_1\anaconda3\lib\site-packages (from pandas-datareader>=0.2->ffn->starfishX) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ann_1\anaconda3\lib\site-packages (from requests->starfishX) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\ann_1\anaconda3\lib\site-packages (from requests->starfishX) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ann_1\anaconda3\lib\site-packages (from requests->starfishX) (2021.10.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ann_1\anaconda3\lib\site-packages (from scikit-learn>=0.15->ffn->starfishX) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\ann_1\anaconda3\lib\site-packages (from scikit-learn>=0.15->ffn->starfishX) (1.1.0)
# Requirement already satisfied: webencodings in c:\users\ann_1\anaconda3\lib\site-packages (from html5lib->starfishX) (0.5.1)
# Collecting PyQt5-sip<13,>=12.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# spyder 5.1.5 requires pyqt5<5.13, but you have pyqt5 5.15.7 which is incompatible.
#   Downloading PyQt5_sip-12.11.0-cp39-cp39-win_amd64.whl (78 kB)
# Collecting PyQt5-Qt5>=5.15.0
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# Collecting tinydb>=3.0
#   Downloading tinydb-4.7.0-py3-none-any.whl (24 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.21.0-py3-none-any.whl (358 kB)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\ann_1\anaconda3\lib\site-packages (from trio~=0.17->selenium->starfishX) (20.3.0)
# Requirement already satisfied: sortedcontainers in c:\users\ann_1\anaconda3\lib\site-packages (from trio~=0.17->selenium->starfishX) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\ann_1\anaconda3\lib\site-packages (from trio~=0.17->selenium->starfishX) (1.14.6)
# Requirement already satisfied: sniffio in c:\users\ann_1\anaconda3\lib\site-packages (from trio~=0.17->selenium->starfishX) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\ann_1\anaconda3\lib\site-packages (from trio~=0.17->selenium->starfishX) (1.10)
# Requirement already satisfied: pycparser in c:\users\ann_1\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium->starfishX) (2.20)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\ann_1\anaconda3\lib\site-packages (from urllib3->starfishX) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\ann_1\anaconda3\lib\site-packages (from urllib3->starfishX) (3.4.8)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\ann_1\anaconda3\lib\site-packages (from urllib3->starfishX) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: colorama in c:\users\ann_1\anaconda3\lib\site-packages (from tqdm->starfishX) (0.4.4)
# Requirement already satisfied: websocket-client in c:\users\ann_1\anaconda3\lib\site-packages (from tvdatafeed->starfishX) (1.3.1)
# Collecting chromedriver-autoinstaller
#   Downloading chromedriver_autoinstaller-0.3.1-py3-none-any.whl (6.3 kB)
# Requirement already satisfied: setuptools in c:\users\ann_1\anaconda3\lib\site-packages (from tvdatafeed->starfishX) (58.0.4)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=93d7cf00caf81b7923f8df1268db84e312adcf6bc8e0daf7e628df7b09d2daf3
#   Stored in directory: c:\users\ann_1\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, tinydb, selenium, PyQt5-sip, PyQt5-Qt5, chromedriver-autoinstaller, tvdatafeed, squarify, sklearn, pythainlp, pyqt5, mplfinance, ffn, starfishX
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.11.0 chromedriver-autoinstaller-0.3.1 ffn-0.3.6 h11-0.13.0 mplfinance-0.12.9b1 outcome-1.2.0 pyqt5-5.15.7 pythainlp-3.0.8 selenium-4.3.0 sklearn-0.0 squarify-0.4.3 starfishX-0.155537 tinydb-4.7.0 trio-0.21.0 trio-websocket-0.9.2 tvdatafeed-1.2.1 wsproto-1.1.0

# %%
import  starfishX as sx
# Out:
# Data Type indexMarket Not Match
# 0

# %%
import pandas as pd
import requests
import urllib.parse
from urllib.request import urlopen as req
import ssl
#import list of set50 name

# %%
# #set_url = r'https://marketdata.set.or.th/mkt/sectorquotation.do?sector=SET50&language=th&country=TH'
# ssl._create_default_https_context = ssl._create_unverified_context
# webopen = req(set_url)
# page_html = webopen.read()
# setdata = pd.read_html(page_html, header= 0)
# set50df= setdata[1].copy()
# set50name = set50df[['หลักทรัพย์']]

# %%
lines_list = open('set50.txt').read().splitlines()
all_set50 = [ line  for line in lines_list]

#assert len(all_set50) == 50

print("SET 50 :\n", all_set50)
# Out:
# SET 50 :
#  ['ADVANC', 'AOT', 'AWC', 'BANPU', 'BBL', 'BDMS', 'BEM', 'BGRIM', 'BH', 'BTS', 'CBG', 'COM7', 'CPALL', 'CPF', 'CPN', 'CRC', 'DTAC', 'EA', 'EGCO', 'GLOBAL', 'GPSC', 'GULF', 'HMPRO', 'INTUCH', 'IRPC', 'IVL', 'KBANK', 'KCE', 'KTB', 'KTC', 'LH', 'MINT', 'MTC', 'OR', 'OSP', 'PTT', 'PTTEP', 'PTTGC', 'RATCH', 'SAWAD', 'SCB', 'SCC', 'SCGP', 'STGT', 'TIDLOR', 'TISCO', 'TOP', 'TRUE', 'TTB', 'TU']

# %%
set50name = pd.DataFrame(all_set50, columns=['set50'])

# %%
set50name = set50name['set50'] + '.bk'

# %%
set50name.values
# Out:
# array(['ADVANC.bk', 'AOT.bk', 'AWC.bk', 'BANPU.bk', 'BBL.bk', 'BDMS.bk',
#        'BEM.bk', 'BGRIM.bk', 'BH.bk', 'BTS.bk', 'CBG.bk', 'COM7.bk',
#        'CPALL.bk', 'CPF.bk', 'CPN.bk', 'CRC.bk', 'DTAC.bk', 'EA.bk',
#        'EGCO.bk', 'GLOBAL.bk', 'GPSC.bk', 'GULF.bk', 'HMPRO.bk',
#        'INTUCH.bk', 'IRPC.bk', 'IVL.bk', 'KBANK.bk', 'KCE.bk', 'KTB.bk',
#        'KTC.bk', 'LH.bk', 'MINT.bk', 'MTC.bk', 'OR.bk', 'OSP.bk',
#        'PTT.bk', 'PTTEP.bk', 'PTTGC.bk', 'RATCH.bk', 'SAWAD.bk', 'SCB.bk',
#        'SCC.bk', 'SCGP.bk', 'STGT.bk', 'TIDLOR.bk', 'TISCO.bk', 'TOP.bk',
#        'TRUE.bk', 'TTB.bk', 'TU.bk'], dtype=object)

# %%
from pandas_datareader import DataReader
from datetime import datetime
close = DataReader(set50name.values, 'yahoo',start=datetime(2018,1,1))['Close']
close
# Out:
# Symbols     ADVANC.bk  AOT.bk  AWC.bk   BANPU.bk  BBL.bk    BDMS.bk  BEM.bk  \
# Date
# 2018-01-03      196.5   70.50     NaN  19.500000   205.0  21.000000    7.75
# 2018-01-04      194.0   70.50     NaN  20.600000   205.0  21.100000    7.70
# 2018-01-05      195.0   72.00     NaN  20.799999   206.0  20.900000    7.90
# 2018-01-08      196.0   74.25     NaN  20.500000   207.0  21.000000    7.80
# 2018-01-09      194.5   73.25     NaN  21.500000   208.0  21.000000    7.85
# ...               ...     ...     ...        ...     ...        ...     ...
# 2022-06-20      203.0   69.25    4.86  12.500000   134.5  24.400000    8.85
# 2022-06-21      201.0   69.75    4.90  12.800000   135.5  24.799999    8.95
# 2022-06-22      198.0   69.50    4.88  12.700000   133.0  24.500000    8.75
# 2022-06-23      197.0   69.00    4.90  12.400000   133.0  24.700001    8.75
# 2022-06-24      202.0   69.75    4.90  12.200000   133.0  24.900000    8.80
#
# Symbols     BGRIM.bk  BH.bk  BTS.bk  ...  SCB.bk  SCC.bk  SCGP.bk    STGT.bk  \
# Date                                 ...
# 2018-01-03     30.25  192.0    8.30  ...     NaN   490.0      NaN        NaN
# 2018-01-04     30.50  194.0    8.30  ...     NaN   496.0      NaN        NaN
# 2018-01-05     31.00  192.5    8.25  ...     NaN   490.0      NaN        NaN
# 2018-01-08     30.50  190.0    8.30  ...     NaN   492.0      NaN        NaN
# 2018-01-09     30.50  192.0    8.45  ...     NaN   496.0      NaN        NaN
# ...              ...    ...     ...  ...     ...     ...      ...        ...
# 2022-06-20     35.50  175.0    8.45  ...   103.0   360.0    52.25  16.799999
# 2022-06-21     35.50  175.0    8.45  ...   105.0   363.0    52.25  17.299999
# 2022-06-22     35.25  174.5    8.35  ...   102.0   364.0    53.00  16.700001
# 2022-06-23     35.75  176.0    8.40  ...   102.0   366.0    53.75  17.000000
# 2022-06-24     36.50  177.5    8.45  ...   104.0   379.0    55.00  17.299999
#
# Symbols     TIDLOR.bk  TISCO.bk  TOP.bk  TRUE.bk    TTB.bk      TU.bk
# Date
# 2018-01-03        NaN     89.50  107.00     6.35  2.816620  20.700001
# 2018-01-04        NaN     90.25  106.50     6.50  2.816620  20.900000
# 2018-01-05        NaN     91.25  107.00     6.40  2.780041  20.799999
# 2018-01-08        NaN     93.25  104.50     6.30  2.761751  20.500000
# 2018-01-09        NaN     93.75  104.00     6.35  2.780041  20.799999
# ...               ...       ...     ...      ...       ...        ...
# 2022-06-20      30.00     89.00   49.50     4.64  1.250000  17.400000
# 2022-06-21      30.00     89.00   51.00     4.76  1.260000  17.400000
# 2022-06-22      29.00     88.75   51.00     4.70  1.250000  17.400000
# 2022-06-23      29.25     89.00   50.25     4.72  1.230000  17.500000
# 2022-06-24      29.25     89.50   49.75     4.74  1.230000  17.500000
#
# [1088 rows x 50 columns]

# %%
close_21 = close.rolling(window=21).mean().round(2)
close_200 = close.rolling(window=200).mean().round(2)

# %%
# up
# 200 < 21 < price
pass_scan_more = []
for i in range(len(close.iloc[-1].index)):
    if close.iloc[-1].values[i] > close_21.iloc[-1].values[i] and close_21.iloc[-1].values[i] > close_200.iloc[-1].values[i]:
        pass_scan_more.append(close.iloc[-1].index[i])
pass_scan_more
# Out:
# ['AOT.bk', 'BBL.bk', 'BH.bk', 'DTAC.bk', 'GULF.bk', 'KBANK.bk', 'TRUE.bk']

# %%
# down
# price < 21 < 200
pass_scan_less = []
for i in range(len(close.iloc[-1].index)):
    if close.iloc[-1].values[i] < close_21.iloc[-1].values[i] and close_21.iloc[-1].values[i] < close_200.iloc[-1].values[i]:
        pass_scan_less.append(close.iloc[-1].index[i])
pass_scan_less
# Out:
# ['ADVANC.bk',
#  'BTS.bk',
#  'COM7.bk',
#  'CPALL.bk',
#  'HMPRO.bk',
#  'INTUCH.bk',
#  'IRPC.bk',
#  'KCE.bk',
#  'KTC.bk',
#  'LH.bk',
#  'MTC.bk',
#  'OSP.bk',
#  'PTT.bk',
#  'PTTGC.bk',
#  'RATCH.bk',
#  'SAWAD.bk',
#  'SCGP.bk',
#  'STGT.bk',
#  'TIDLOR.bk',
#  'TISCO.bk',
#  'TTB.bk']

# %%
# sideway ?
# 200 < price < 21 
pass_scan_less = []
for i in range(len(close.iloc[-1].index)):
    if close.iloc[-1].values[i] < close_21.iloc[-1].values[i] and close_21.iloc[-1].values[i] > close_200.iloc[-1].values[i]:
        pass_scan_less.append(close.iloc[-1].index[i])
pass_scan_less
# Out:
# ['AWC.bk',
#  'BANPU.bk',
#  'BDMS.bk',
#  'BEM.bk',
#  'CPF.bk',
#  'CPN.bk',
#  'CRC.bk',
#  'EA.bk',
#  'EGCO.bk',
#  'GLOBAL.bk',
#  'IVL.bk',
#  'KTB.bk',
#  'MINT.bk',
#  'OR.bk',
#  'PTTEP.bk',
#  'TOP.bk']

# %%
# reversal ?
# 21 < price < 200 
pass_scan_less = []
for i in range(len(close.iloc[-1].index)):
    if close.iloc[-1].values[i] > close_21.iloc[-1].values[i] and close_21.iloc[-1].values[i] < close_200.iloc[-1].values[i]:
        pass_scan_less.append(close.iloc[-1].index[i])
pass_scan_less
# Out:
# ['BGRIM.bk', 'CBG.bk', 'GPSC.bk', 'SCC.bk', 'TU.bk']
